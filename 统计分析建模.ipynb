# %%
import pandas as pd
import os

# %%
df=pd.read_csv('data.csv')
df.head()
# Out:
#                                               SMILES  nAcid   ALogP    ALogp2  \
# 0  Oc1ccc2O[C@H]([C@H](Sc2c1)C3CCCC3)c4ccc(OCCN5C...      0 -0.2860  0.081796
# 1  Oc1ccc2O[C@H]([C@H](Sc2c1)C3CCCCCC3)c4ccc(OCCN...      0 -0.8620  0.743044
# 2  Oc1ccc(cc1)[C@H]2Sc3cc(O)ccc3O[C@H]2c4ccc(OCCN...      0  0.7296  0.532316
# 3  Oc1ccc2O[C@H]([C@@H](CC3CCCCC3)Sc2c1)c4ccc(OCC...      0 -0.3184  0.101379
# 4  Oc1ccc2O[C@H]([C@@H](Cc3ccccc3)Sc2c1)c4ccc(OCC...      0  1.3551  1.836296
#
#         AMR       apol  naAromAtom  nAromBond  nAtom  nHeavyAtom  ...  WPATH  \
# 0  126.1188  74.170169          12         12     64          31  ...   3011
# 1  131.9420  80.357341          12         12     70          33  ...   3516
# 2  139.9304  74.064997          18         18     62          33  ...   3542
# 3  133.4822  80.357341          12         12     70          33  ...   3594
# 4  143.1903  76.356583          18         18     64          33  ...   3594
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                                  SMILES  nAcid   ALogP  \
# 0     Oc1ccc2O[C@H]([C@H](Sc2c1)C3CCCC3)c4ccc(OCCN5C...      0 -0.2860
# 1     Oc1ccc2O[C@H]([C@H](Sc2c1)C3CCCCCC3)c4ccc(OCCN...      0 -0.8620
# 2     Oc1ccc(cc1)[C@H]2Sc3cc(O)ccc3O[C@H]2c4ccc(OCCN...      0  0.7296
# 3     Oc1ccc2O[C@H]([C@@H](CC3CCCCC3)Sc2c1)c4ccc(OCC...      0 -0.3184
# 4     Oc1ccc2O[C@H]([C@@H](Cc3ccccc3)Sc2c1)c4ccc(OCC...      0  1.3551
# ...                                                 ...    ...     ...
# 1969  COc1cc(OC)cc(\C=C\c2cccc(OS(=O)(=O)C3CC4OC3C(=...      0  1.8193
# 1970  Oc1ccc(cc1)C2=C(C3OC2CC3S(=O)(=O)Oc4cccc(\C=C\...      0  1.6903
# 1971  Oc1ccc(cc1)C2=C(C3OC2CC3S(=O)(=O)Oc4ccc(\C=C\c...      0  1.6903
# 1972  Oc1ccc(cc1)C2=C([C@H]3O[C@H]2C[C@@H]3S(=O)(=O)...      0  1.3365
# 1973  COc1cc(OC)cc(\C=C\c2ccc(OS(=O)(=O)[C@H]3C[C@H]...      0  1.8193
#
#         ALogp2       AMR       apol  naAromAtom  nAromBond  nAtom  nHeavyAtom  \
# ...

# %%
df.drop_duplicates()
# Out:
#                                                  SMILES  nAcid   ALogP  \
# 0     Oc1ccc2O[C@H]([C@H](Sc2c1)C3CCCC3)c4ccc(OCCN5C...      0 -0.2860
# 1     Oc1ccc2O[C@H]([C@H](Sc2c1)C3CCCCCC3)c4ccc(OCCN...      0 -0.8620
# 2     Oc1ccc(cc1)[C@H]2Sc3cc(O)ccc3O[C@H]2c4ccc(OCCN...      0  0.7296
# 3     Oc1ccc2O[C@H]([C@@H](CC3CCCCC3)Sc2c1)c4ccc(OCC...      0 -0.3184
# 4     Oc1ccc2O[C@H]([C@@H](Cc3ccccc3)Sc2c1)c4ccc(OCC...      0  1.3551
# ...                                                 ...    ...     ...
# 1969  COc1cc(OC)cc(\C=C\c2cccc(OS(=O)(=O)C3CC4OC3C(=...      0  1.8193
# 1970  Oc1ccc(cc1)C2=C(C3OC2CC3S(=O)(=O)Oc4cccc(\C=C\...      0  1.6903
# 1971  Oc1ccc(cc1)C2=C(C3OC2CC3S(=O)(=O)Oc4ccc(\C=C\c...      0  1.6903
# 1972  Oc1ccc(cc1)C2=C([C@H]3O[C@H]2C[C@@H]3S(=O)(=O)...      0  1.3365
# 1973  COc1cc(OC)cc(\C=C\c2ccc(OS(=O)(=O)[C@H]3C[C@H]...      0  1.8193
#
#         ALogp2       AMR       apol  naAromAtom  nAromBond  nAtom  nHeavyAtom  \
# ...

# %%
df.dropna()
# Out:
#                                                  SMILES  nAcid   ALogP  \
# 0     Oc1ccc2O[C@H]([C@H](Sc2c1)C3CCCC3)c4ccc(OCCN5C...      0 -0.2860
# 1     Oc1ccc2O[C@H]([C@H](Sc2c1)C3CCCCCC3)c4ccc(OCCN...      0 -0.8620
# 2     Oc1ccc(cc1)[C@H]2Sc3cc(O)ccc3O[C@H]2c4ccc(OCCN...      0  0.7296
# 3     Oc1ccc2O[C@H]([C@@H](CC3CCCCC3)Sc2c1)c4ccc(OCC...      0 -0.3184
# 4     Oc1ccc2O[C@H]([C@@H](Cc3ccccc3)Sc2c1)c4ccc(OCC...      0  1.3551
# ...                                                 ...    ...     ...
# 1969  COc1cc(OC)cc(\C=C\c2cccc(OS(=O)(=O)C3CC4OC3C(=...      0  1.8193
# 1970  Oc1ccc(cc1)C2=C(C3OC2CC3S(=O)(=O)Oc4cccc(\C=C\...      0  1.6903
# 1971  Oc1ccc(cc1)C2=C(C3OC2CC3S(=O)(=O)Oc4ccc(\C=C\c...      0  1.6903
# 1972  Oc1ccc(cc1)C2=C([C@H]3O[C@H]2C[C@@H]3S(=O)(=O)...      0  1.3365
# 1973  COc1cc(OC)cc(\C=C\c2ccc(OS(=O)(=O)[C@H]3C[C@H]...      0  1.8193
#
#         ALogp2       AMR       apol  naAromAtom  nAromBond  nAtom  nHeavyAtom  \
# ...

# %%
df.describe()
# Out:
#              nAcid        ALogP        ALogp2          AMR         apol  \
# count  1974.000000  1974.000000  1.974000e+03  1974.000000  1974.000000
# mean      0.108409     1.110164  3.288495e+00   116.557106    60.626471
# std       0.347900     1.434250  1.283292e+01    31.567455    19.449748
# min       0.000000   -23.105000  3.600000e-07    54.067000    30.661930
# 25%       0.000000     0.376300  4.052598e-01    88.303700    44.432102
# 50%       0.000000     1.170950  1.560251e+00   114.837500    59.901376
# 75%       0.000000     1.948100  4.018823e+00   141.423650    74.421376
# max       4.000000     5.181700  5.338410e+02   517.429400   359.662740
#
#         naAromAtom    nAromBond        nAtom   nHeavyAtom           nH  ...  \
# count  1974.000000  1974.000000  1974.000000  1974.000000  1974.000000  ...
# mean     15.446809    16.189463    50.761905    28.112462    22.649443  ...
# std       5.155854     5.635271    18.089182     8.073881    10.775491  ...
# ...

# %%
p=df.boxplot(return_type='dict')

# %%
 for index,value in enumerate(df.columns):
  # 获取异常值
  fliers_value_list = p['fliers'][index].get_ydata()
  # 删除异常值
  for flier in fliers_value_list:
   df = df[df.loc[:,value] != flier]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-d0153768ab78> in <module>
#       1 for index,value in enumerate(df.columns):
#       2  # 获取异常值
# ----> 3  fliers_value_list = p['fliers'][index].get_ydata()
#       4  # 删除异常值
#       5  for flier in fliers_value_list:
#
# IndexError: list index out of range
